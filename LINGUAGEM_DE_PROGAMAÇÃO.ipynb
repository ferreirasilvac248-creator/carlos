# %% [markdown]
# <a href="https://colab.research.google.com/github/ferreirasilvac248-creator/carlos/blob/main/LINGUAGEM_DE_PROGAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###U1_A1

# %%
#1.Nosso primeiro progama
print("hello world")
hello word
# Out:
#   File "/tmp/ipykernel_888/475473155.py", line 3
#     hello word
#           ^
# SyntaxError: invalid syntax

# %%
#2.criando variaveis de tipos diferentes

# %%
X = 10

# %%
#2.criando variaveis de tipos diferentes
X =10
nome = 'Carlos'
nota = 8.75
fez_inscricao = True

# %%
print(X)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Carlos
# 8.75
# True

# %%
print(type(X))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input('digite o seu nome:')
# Out:
# digite o seu nome:Carlos

# %%
print(f'olá (nome), bem vindo à disciplina de progamacao')
# Out:
# olá (nome), bem vindo à disciplina de progamacao

# %%
Nota_1 = int(input('digite a nota 1: '))
Nota_2 = int(input('digite a nota 2: '))
Nota_3 = int(input('digite a nota 3: '))
Nota_4 = int(input('digite a nota 4: ' ))
# Out:
# digite a nota 1: 5
# digite a nota 2: 6
# digite a nota 3: 7
# digite a nota 4: 8

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# 6.5

# %%
if media >= 6:
  print('Aprovado')
else:
  print('Reprovado')

# %% [markdown]
# ##U1-A2

# %%
print(1>5)
# Out:
# False

# %%
print(7!=7)
# Out:
# False

# %%
#aguardando informacao
idade =20
e_maior_de_idade =idade>=18
print(e_maior_de_idade)
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
idade = int(input('digite sua idade: '))
if idade < 18:
    print('menor de idade')
elif idade >= 18 and idade < 60:
    print('adulto')
else:
    print('idoso')
# Out:
# digite sua idade: 66
# idoso

# %%
idade = int(input('digite sua idade: '))
if idade < 18:
    print('recomendamos o filme infantil 1')
elif idade >= 12 and idade < 18:
    print('recomendamos o filme infantil 2')
# Out:
# digite sua idade: 10
# recomendamos o filme infantil 1

# %%
print('recomendamos o filme infantil 3')
quantidade_de_ingressos = 30
if quantidade_de_ingressos > 0:
    print("ingressos disponiveis. Divirta-se no cinema")
else:
    print("desculpe todos os ingressos foram vendidos.")
# Out:
# recomendamos o filme infantil 3
# ingressos disponiveis. Divirta-se no cinema

# %% [markdown]
# ##U1_A3

# %%
numeros =(1,2,3,4,5)
for numeros in numeros :
  print(numeros)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
from os import X_OK
for X in range (1,15,3):
  print(X)
# Out:
# 1
# 4
# 7
# 10
# 13

# %%
filmes_lista = ["Filme 1", "Filme 2", "Filme 3", "Filme 4", "Filme 5"] # Changed to a list of film names
print("bem vindo a classificacao dos filmes ")
print ("voce tem cinco filmes para classificar")
print (" digite '0' a qualquer momento parar.\n")

for filme_item in filmes_lista : # Corrected iterable and loop variable
  classificacao_str = input(f"como voce classifica '{filme_item}' de 1 a 5 (ou 0 para parar): ") # Corrected f-string
  if classificacao_str == '0':
    print("Que pena, você decidiu parar a classificação.")
    break # Correctly placed break

  try:
    classificacao = int(classificacao_str) # Corrected typo and type conversion
    if classificacao < 1 or classificacao > 5:
      print ("Nota inválida. Por favor, classifique de 1 a 5.")
    else: # Corrected indentation for else
      print(f"Você classificou '{filme_item}' com = '{classificacao}' estrelas.\n") # Corrected indentation and f-string
  except ValueError:
    print("Entrada inválida. Por favor, digite um número inteiro de 0 a 5.")

print("Obrigado por suas classificações!") # Moved outside the loop and conditional
# Out:
# bem vindo a classificacao dos filmes
# voce tem cinco filmes para classificar
#  digite '0' a qualquer momento parar.
#
# como voce classifica 'Filme 1' de 1 a 5 (ou 0 para parar): 1
# Você classificou 'Filme 1' com = '1' estrelas.
#
# como voce classifica 'Filme 2' de 1 a 5 (ou 0 para parar): 2
# Você classificou 'Filme 2' com = '2' estrelas.
#
# como voce classifica 'Filme 3' de 1 a 5 (ou 0 para parar): 3
# Você classificou 'Filme 3' com = '3' estrelas.
#
# como voce classifica 'Filme 4' de 1 a 5 (ou 0 para parar): 4
# Você classificou 'Filme 4' com = '4' estrelas.
#
# como voce classifica 'Filme 5' de 1 a 5 (ou 0 para parar): 5
# Você classificou 'Filme 5' com = '5' estrelas.
#
# Obrigado por suas classificações!
