# %% [markdown]
# <a href="https://colab.research.google.com/github/ferreirasilvac248-creator/carlos/blob/main/LINGUAGEM_DE_PROGAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###U1_A1

# %%
#1.Nosso primeiro progama
print("hello world")
print("hello word")
# Out:
# hello world
# hello word

# %%
#2.criando variaveis de tipos diferentes

# %%
X = 10

# %%
#2.criando variaveis de tipos diferentes
X =10
nome = 'Carlos'
nota = 8.75
fez_inscricao = True

# %%
print(X)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Carlos
# 8.75
# True

# %%
print(type(X))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input('digite o seu nome:')
# Out:
# digite o seu nome:Carlos

# %%
print(f'olá (nome), bem vindo à disciplina de progamacao')
# Out:
# olá (nome), bem vindo à disciplina de progamacao

# %%
Nota_1 = int(input('digite a nota 1: '))
Nota_2 = int(input('digite a nota 2: '))
Nota_3 = int(input('digite a nota 3: '))
Nota_4 = int(input('digite a nota 4: ' ))
# Out:
# digite a nota 1: 5
# digite a nota 2: 6
# digite a nota 3: 7
# digite a nota 4: 8

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# 6.5

# %%
if media >= 6:
  print('Aprovado')
else:
  print('Reprovado')

# %% [markdown]
# ##U1-A2

# %%
print(1>5)
# Out:
# False

# %%
print(7!=7)
# Out:
# False

# %%
#aguardando informacao
idade =20
e_maior_de_idade =idade>=18
print(e_maior_de_idade)
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
idade = int(input('digite sua idade: '))
if idade < 18:
    print('menor de idade')
elif idade >= 18 and idade < 60:
    print('adulto')
else:
    print('idoso')
# Out:
# digite sua idade: 66
# idoso

# %%
idade = int(input('digite sua idade: '))
if idade < 18:
    print('recomendamos o filme infantil 1')
elif idade >= 12 and idade < 18:
    print('recomendamos o filme infantil 2')
# Out:
# digite sua idade: 10
# recomendamos o filme infantil 1

# %%
print('recomendamos o filme infantil 3')
quantidade_de_ingressos = 30
if quantidade_de_ingressos > 0:
    print("ingressos disponiveis. Divirta-se no cinema")
else:
    print("desculpe todos os ingressos foram vendidos.")
# Out:
# recomendamos o filme infantil 3
# ingressos disponiveis. Divirta-se no cinema

# %% [markdown]
# ##U1_A4

# %%
numero = (1,2,3,4,5)
comprimento = len(numero)

# %%
comprimento
5
# Out:
# 5

# %%
range (5)
range (0,5)
# Out:
# range(0, 5)

# %%
 def soma (a,b):
  resultado = a + b
  return resultado

# %%
resultado_soma = soma(5,6)

# %%
print(resultado_soma)
# Out:
# 11

# %%
def e_par(numero):
  if numero * 2 == 0:
    return True
  else:
    return False

# %%
def e_primo(numero):
  if numero < 2:
    return False
  for i in range(2, int(numero**0.5) + 1):
    if numero % i == 0:
      return False
  return True

# %%
numero  = 72468
teste = e_primo (numero)

# %%
print(teste)
# Out:
# False

# %%
media = 8.232365498
arredondar_media = lambda media: round(media, 2)

# %%
media_arrendodada = arredondar_media(media)
print(media_arrendodada)
# Out:
# 8.23

# %% [markdown]
# ENCERRAMENTO

# %%
##funcoes definidas pelo usuario
def calcular_desconto (valor,percentual):
  """ calcule o valor final aplicando um desconto percentual,"""
  if percentual < 0 or percentual >100:
    return nome # marcacao invalida
    desconto # valor # (percentual/100)
    return valor - desconto
    f registrar_venda(produto,valor_final):
  """imprime o registro de uma venda."""
  print (f">>venda registrada : {produto} por R$ {valor_final:.2f}")

#funcao lambda para arrendodar
arredondar_media = lambda media: round(media, 2)

# %%
#variaveis principais  do Pdv
total_vendas = 0
qtd_vendas = 0

# %%
import math # Import math for rounding if not using a custom function

# Placeholder definitions for functions/variables that might be defined in other cells
# These are included here to make the current cell runnable in isolation,
# but you should ensure they are correctly defined in their intended cells.
# Assuming 'calcular_desconto' returns None for invalid percentual
def calcular_desconto(valor, percentual):
    if percentual < 0 or percentual > 100:
        return None
    desconto = valor * (percentual / 100)
    return valor - desconto

# Assuming 'registrar_venda' is defined elsewhere
def registrar_venda(produto, valor_final):
    print(f">> Venda registrada: {produto} por R$ {valor_final:.2f}")

# Assuming 'arredondar_media' is defined elsewhere as a lambda or function
arredondar_media = lambda x: round(x, 2)

# Variables that should be initialized globally or before the loop
total_vendas = 0
qtd_vendas = 0

# loop principal do caixa. MINHALOJAPDV
while True: # Changed 'true' to 'True'
  print (" \n_ _ _ _ _ minha loja _ pdv _ _ _ _ _")
  print (" 1 _ Registrar Venda ")
  print("2 _ Ver relatório  do dia ")
  print ("3 _ Encerrar Caixa ") # Corrected indentation

  opcao = input("Digite a opção: ") # Added input for 'opcao'

  if opcao == '3' or opcao == '0': # Assuming '3' is also to exit, and '0' was a typo or alternative
    print("Encerrando o caixa. Até amanhã!")
    break

  elif opcao == '1':
    produto = input("Digite o nome do produto: ")
    # Removed redundant 'valor' input line
    valor = float(input("Digite o valor do produto: R$ "))
    percentual = float(input("Digite o percentual de desconto (0-100): ")) # Uncommented and made active
    valor_final = calcular_desconto(valor, percentual)

    # Corrected indentation, variable name, and 'Nome' to 'None'
    if valor_final is None:
      print("Desconto inválido: Use um valor entre 0 e 100.")
    else: # Corrected indentation
      # Corrected variable name and function call (assuming arredondar_media is available)
      valor_final = arredondar_media(valor_final)
      # Corrected function call (assuming registrar_venda is defined correctly elsewhere)
      registrar_venda(produto, valor_final)
      total_vendas = total_vendas + valor_final
      qtd_vendas = qtd_vendas + 1

  elif opcao == "2": # Corrected syntax from 'else opcao = "2" :' to 'elif opcao == "2":'
    print(f"\nVendas hoje: {qtd_vendas}")
    # Corrected function call
    print(f"Total de vendas: R$ {arredondar_media(total_vendas)}")

  else: # Corrected syntax from 'else' to 'else:' and adjusted indentation
    print("Opção inválida. Tente de novo.")
# Out:
#
# _ _ _ _ _ minha loja _ pdv _ _ _ _ _
#  1 _ Registrar Venda
# 2 _ Ver relatório  do dia
# 3 _ Encerrar Caixa
# Digite a opção: 1
# Digite o nome do produto: Maca
# Digite o valor do produto: R$ 20
# Digite o percentual de desconto (0-100): 10
# >> Venda registrada: Maca por R$ 18.00
#
# _ _ _ _ _ minha loja _ pdv _ _ _ _ _
#  1 _ Registrar Venda
# 2 _ Ver relatório  do dia
# 3 _ Encerrar Caixa
# Digite a opção: 1
# Digite o nome do produto: leite
# Digite o valor do produto: R$ 5
# Digite o percentual de desconto (0-100): 4
# >> Venda registrada: leite por R$ 4.80
#
# _ _ _ _ _ minha loja _ pdv _ _ _ _ _
#  1 _ Registrar Venda
# 2 _ Ver relatório  do dia
# 3 _ Encerrar Caixa
# Digite a opção: 2
#
# Vendas hoje: 2
# Total de vendas: R$ 22.8
#
# _ _ _ _ _ minha loja _ pdv _ _ _ _ _
#  1 _ Registrar Venda
# 2 _ Ver relatório  do dia
# 3 _ Encerrar Caixa
# Digite a opção: 3
# Encerrando o caixa. Até amanhã!
